# %%
import pandas as pd
healthcare = pd.read_csv("C:/Users/vyshu/Downloads/watson_healthcare_modified.csv")
healthcare.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 0     1313919   41        No      Travel_Rarely       1102  Cardiology
# 1     1200302   49        No  Travel_Frequently        279   Maternity
# 2     1060315   37       Yes      Travel_Rarely       1373   Maternity
# 3     1272912   33        No  Travel_Frequently       1392   Maternity
# 4     1414939   27        No      Travel_Rarely        591   Maternity
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 0                         1            80      0                  8
# ...

# %%
healthcare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1676 entries, 0 to 1675
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeID                1676 non-null   int64
#  1   Age                       1676 non-null   int64
#  2   Attrition                 1676 non-null   object
#  3   BusinessTravel            1676 non-null   object
#  4   DailyRate                 1676 non-null   int64
#  5   Department                1676 non-null   object
#  6   DistanceFromHome          1676 non-null   int64
#  7   Education                 1676 non-null   int64
#  8   EducationField            1676 non-null   object
#  9   EmployeeCount             1676 non-null   int64
#  10  EnvironmentSatisfaction   1676 non-null   int64
#  11  Gender                    1676 non-null   object
#  12  HourlyRate                1676 non-null   int64
#  13  JobInvolvement            1676 non-null   int64
# ...

# %%
healthcare['Yearly_Increment'] = 12*healthcare["MonthlyIncome"]*healthcare["PercentSalaryHike"]
healthcare['Promotion_time'] = healthcare['YearsInCurrentRole'] - healthcare['YearsSinceLastPromotion']

# %%
healthcare["Attrition"].value_counts()
# Out:
# No     1477
# Yes     199
# Name: Attrition, dtype: int64

# %%
healthcare["Attrition"].value_counts() / len(healthcare)
# Out:
# No     0.881265
# Yes    0.118735
# Name: Attrition, dtype: float64

# %%
healthcare["Department"].value_counts()
# Out:
# Maternity     796
# Cardiology    531
# Neurology     349
# Name: Department, dtype: int64

# %%
healthcare["BusinessTravel"].value_counts()
# Out:
# Travel_Rarely        1184
# Travel_Frequently     320
# Non-Travel            172
# Name: BusinessTravel, dtype: int64

# %%
healthcare["EducationField"].value_counts()
# Out:
# Life Sciences       697
# Medical             524
# Marketing           189
# Technical Degree    149
# Other                88
# Human Resources      29
# Name: EducationField, dtype: int64

# %%
healthcare["JobRole"].value_counts()
# Out:
# Nurse             822
# Other             534
# Therapist         189
# Administrative    115
# Admin              16
# Name: JobRole, dtype: int64

# %%
healthcare["MaritalStatus"].value_counts()
# Out:
# Married     777
# Single      522
# Divorced    377
# Name: MaritalStatus, dtype: int64

# %%
healthcare["Over18"].value_counts()
# Out:
# Y    1676
# Name: Over18, dtype: int64

# %%
healthcare["OverTime"].value_counts()
# Out:
# No     1200
# Yes     476
# Name: OverTime, dtype: int64

# %%
healthcare["Gender"].value_counts()
# Out:
# Male      998
# Female    678
# Name: Gender, dtype: int64

# %%
healthcare.describe().T
# Out:
#                            count          mean            std        min  \
# EmployeeID                1676.0  1.456796e+06  248748.624383  1025177.0
# Age                       1676.0  3.686635e+01       9.129126       18.0
# DailyRate                 1676.0  8.005579e+02     401.594438      102.0
# DistanceFromHome          1676.0  9.221957e+00       8.158118        1.0
# Education                 1676.0  2.907518e+00       1.025835        1.0
# EmployeeCount             1676.0  1.000000e+00       0.000000        1.0
# EnvironmentSatisfaction   1676.0  2.714797e+00       1.097534        1.0
# HourlyRate                1676.0  6.547017e+01      20.207572       30.0
# JobInvolvement            1676.0  2.724940e+00       0.714121        1.0
# JobLevel                  1676.0  2.066826e+00       1.113423        1.0
# JobSatisfaction           1676.0  2.738663e+00       1.104005        1.0
# MonthlyIncome             1676.0  6.516513e+03    4728.456618     1009.0
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
healthcare.hist(bins=50, figsize=(20,15))
plt.show()

# %%
healthcare['Attrition'] = [1 if each == 'Yes' else 0 for each in healthcare['Attrition']]
healthcare['Gender'] = [1 if each == 'Male' else 0 for each in healthcare['Gender']]
healthcare['OverTime'] = [1 if each == 'Yes' else 0 for each in healthcare['OverTime']]

# %%
healthcare = healthcare.drop(['Over18', 'EmployeeCount', 'StandardHours', 'EmployeeID'], axis=1)

# %%
corr_matrix = healthcare.corr()
corr_matrix["Attrition"].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# OverTime                    0.337383
# DistanceFromHome            0.105580
# MonthlyRate                 0.045744
# NumCompaniesWorked          0.017279
# PerformanceRating           0.010728
# PercentSalaryHike           0.002943
# RelationshipSatisfaction   -0.020462
# Gender                     -0.020661
# HourlyRate                 -0.036300
# Education                  -0.038843
# DailyRate                  -0.053892
# TrainingTimesLastYear      -0.054836
# JobSatisfaction            -0.081881
# YearsSinceLastPromotion    -0.086207
# WorkLifeBalance            -0.090513
# EnvironmentSatisfaction    -0.101278
# Promotion_time             -0.145133
# Shift                      -0.158322
# JobInvolvement             -0.166036
# Yearly_Increment           -0.185001
# MonthlyIncome              -0.193527
# YearsWithCurrManager       -0.201087
# YearsAtCompany             -0.201373
# JobLevel                   -0.207634
# ...

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.countplot(x='Age',hue='Attrition',data=healthcare)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='DistanceFromHome',hue='Attrition',data=healthcare)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='EnvironmentSatisfaction',hue='Attrition',data=healthcare)
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='JobSatisfaction',hue='Attrition',data=healthcare)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='JobLevel',hue='Attrition',data=healthcare)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %%
healthcare.groupby('Attrition')['MonthlyIncome'].mean()
# Out:
# Attrition
# 0    6852.301963
# 1    4024.246231
# Name: MonthlyIncome, dtype: float64

# %%
healthcare = pd.get_dummies(healthcare)

# %%
healthcare.head().T
# Out:
#                                        0        1       2       3       4
# Age                                   41       49      37      33      27
# Attrition                              0        0       1       0       0
# DailyRate                           1102      279    1373    1392     591
# DistanceFromHome                       1        8       2       3       2
# Education                              2        1       2       4       1
# EnvironmentSatisfaction                2        3       4       4       1
# Gender                                 0        1       1       0       1
# HourlyRate                            94       61      92      56      40
# JobInvolvement                         3        2       2       3       3
# JobLevel                               2        2       1       1       1
# JobSatisfaction                        4        2       3       3       2
# MonthlyIncome                       5993     5130    2090    2909    3468
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(healthcare)
# Out:
# array([[ 0.45293334, -0.36705935,  0.75083732, ..., -0.53872372,
#         -0.92967395,  1.4868517 ],
#        [ 1.32951102, -0.36705935, -1.2991055 , ..., -0.53872372,
#          1.07564593, -0.67256203],
#        [ 0.0146445 ,  2.72435507,  1.42584887, ..., -0.53872372,
#         -0.92967395,  1.4868517 ],
#        ...,
#        [-1.84808308, -0.36705935,  0.39465042, ..., -0.53872372,
#         -0.92967395,  1.4868517 ],
#        [ 0.23378892, -0.36705935, -0.83332262, ..., -0.53872372,
#          1.07564593, -0.67256203],
#        [-1.08107761, -0.36705935, -0.72123583, ..., -0.53872372,
#         -0.92967395,  1.4868517 ]])

# %%
import numpy as np
healthcare['MonthlyIncome'] = np.log10(healthcare['MonthlyIncome'])

healthcare['Yearly_Increment'] = np.log10(healthcare['Yearly_Increment'])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(healthcare, healthcare["Attrition"]):
    strat_train_set = healthcare.loc[train_index]
    strat_test_set = healthcare.loc[test_index]

# %%
strat_test_set["Attrition"].value_counts() / len(strat_test_set)
# Out:
# 0    0.880952
# 1    0.119048
# Name: Attrition, dtype: float64

# %%
healthcare["Attrition"].value_counts() / len(healthcare)
# Out:
# 0    0.881265
# 1    0.118735
# Name: Attrition, dtype: float64

# %%
strat_train_set.head().T
# Out:
#                                           417           243           1628  \
# Age                                  40.000000     40.000000     25.000000
# Attrition                             0.000000      0.000000      0.000000
# DailyRate                          1398.000000   1300.000000    622.000000
# DistanceFromHome                      2.000000     24.000000     13.000000
# Education                             4.000000      2.000000      1.000000
# EnvironmentSatisfaction               3.000000      1.000000      2.000000
# Gender                                0.000000      1.000000      1.000000
# HourlyRate                           79.000000     62.000000     40.000000
# JobInvolvement                        3.000000      3.000000      3.000000
# JobLevel                              5.000000      2.000000      1.000000
# JobSatisfaction                       3.000000      4.000000      3.000000
# ...

# %%
healthcare = strat_train_set.drop('Attrition', axis = 1)
attrition = strat_train_set['Attrition']
test = strat_test_set.drop('Attrition', axis = 1)
y_test = strat_test_set['Attrition']

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(n_jobs = -1)
model.fit(healthcare, attrition)
y_pred = model.predict(test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8958333333333334
